# %%
# %cd -q ..

from IPython.display import display

import graphviz

dot = graphviz.Digraph()
dot.edges(['AB', 'BC', 'AC'])

for engine in sorted(graphviz.ENGINES):
    print(engine)
    dot.engine = engine
    display(dot)
    print()
# Out:
# circo
# dot
# fdp
# neato
# osage
# patchwork
# sfdp
# twopi
